# %% [markdown]
# <a href="https://colab.research.google.com/github/ashfarhangi/Massive_Storage_and_Big_Data/blob/master/code/1_Python_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gentle Introduction to Python and Its Applications
# In this guide we take look at the following:
# 1. Programming Environment
# 2. Python Basics
# 3. Data manipulation

# %% [markdown]
# ## 1. Programming Environment
#
# Introduction to Jupyter Environment

# %% [markdown]
# > "Instead of imagining that our main task is to instruct a computer what to do, let us concentrate rather on explaining to human beings what we want a computer to do."
# > **Donald Knuth**

# %% [markdown]
# In this session we look at literate programming where documentation is written as a narrative alongside the code instead of sitting off by its own.
# We also get familiar with basics of python for the Massive Storage and Big Data

# %% [markdown]
# The jupyter notebook can hold both python code and text alongside each other, lets look at the behaviour of this notebook
#
#
#
# ![notebook-components.png](data:image/png;base64,...)

# %% [markdown]
# The notebook server (locally or online) can show your Notebook file (.ipynb) short form of python.

# %%
from psutil import *
cpu_count()
# Out:
# 2

# %% [markdown]
# available storage:

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   31G   73G  30% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   12K  6.4G   1% /var/colab
# /dev/sda1       114G   32G   83G  28% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13333552 kB
# MemFree:        10781164 kB
# MemAvailable:   12521124 kB
# Buffers:           74924 kB
# Cached:          1769816 kB
# SwapCached:            0 kB
# Active:           665480 kB
# Inactive:        1626248 kB
# Active(anon):     372124 kB
# Inactive(anon):      328 kB
# Active(file):     293356 kB
# Inactive(file):  1625920 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              5980 kB
# Writeback:             0 kB
# AnonPages:        446948 kB
# Mapped:           182784 kB
# Shmem:               928 kB
# Slab:             159992 kB
# SReclaimable:     123052 kB
# SUnreclaim:        36940 kB
# KernelStack:        3712 kB
# PageTables:         5020 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666776 kB
# Committed_AS:    2569796 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13333552 kB
# MemFree:        10780772 kB
# MemAvailable:   12520724 kB
# Buffers:           74924 kB
# Cached:          1769816 kB
# SwapCached:            0 kB
# Active:           666032 kB
# Inactive:        1626236 kB
# Active(anon):     372672 kB
# Inactive(anon):      328 kB
# Active(file):     293360 kB
# Inactive(file):  1625908 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              6128 kB
# Writeback:             0 kB
# AnonPages:        447648 kB
# Mapped:           182924 kB
# Shmem:               928 kB
# Slab:             159952 kB
# SReclaimable:     123056 kB
# SUnreclaim:        36896 kB
# KernelStack:        3680 kB
# PageTables:         4932 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666776 kB
# Committed_AS:    2545776 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
#!cat /proc/cpuinfo
#!df -h
#!cat /proc/meminfo
# !lscpu |grep 'Model name'

# %% [markdown]
# ### Linux environment

# %% [markdown]
# You can look at the linux environment below:

# %%
# !cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.3 LTS"
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %% [markdown]
# Basic linux command:

# %%
# !pwd
# Out:
# /content

# %%
# !wget  https://dl.fbaipublicfiles.com/XLM/cdes_xnli_100o
# Out:
# --2020-09-12 14:17:04--  https://dl.fbaipublicfiles.com/XLM/cdes_xnli_100o
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2020-09-12 14:17:05 ERROR 403: Forbidden.

# %%
# !ls -l
# Out:
# total 3316
# -rw-r--r-- 1 root root 1692256 Feb 14  2020 2bb.gif
# -rw-r--r-- 1 root root 1692256 Feb 14  2020 2bb.gif.1
# drwxr-xr-x 1 root root    4096 Aug 27 16:39 sample_data

# %% [markdown]
# You can use the '!' character to communicate with the linux enviornment. For example lets look at the python version installed in our environment

# %%
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# ## Python Basics

# %% [markdown]
# ### How Python is different from other languages?

# %% [markdown]
# Python is an interpreted and dynamically typed language, whereas Java is a compiled and statically typed language.
# - In java your program need to compiled, but in Python you can write 1 line of code and have show its results
# - lightning-fast development speed ⚡
# - Extremely user-friendly 😊
#
#
# All in all it brought alot of people from different backgrounds into programming. That's why we have a lot of libraries available for different problems
#
# This trend is predictable as many low-level programming like ASEMBLY is used today in rare cases.

# %% [markdown]
# Example simple calculation

# %%
float(3 * 2)
# Out:
# 6.0

# %% [markdown]
# ### Quiz:
# - Calculate and show the number seconds in two years:

# %% [markdown]
# - Divide the answer by 13

# %% [markdown]
# -

# %% [markdown]
# ### Input and Output
# Reading and Writing Files
# It is good practice to use the **with** keyword when dealing with file objects. Since we might need to close the file after its shown

# %%
from IPython.display import Image
# !wget https://i.kym-cdn.com/photos/images/original/001/745/592/2bb.gif

with open('/content/2bb.gif','rb') as f:
    display(Image(data=f.read(), format='png'))
# Out:
# --2020-09-12 14:17:05--  https://i.kym-cdn.com/photos/images/original/001/745/592/2bb.gif
# Resolving i.kym-cdn.com (i.kym-cdn.com)... 8.240.26.252, 8.253.254.252, 8.253.45.220
# Connecting to i.kym-cdn.com (i.kym-cdn.com)|8.240.26.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1692256 (1.6M) [image/gif]
# Saving to: ‘2bb.gif.2’
#
# 2bb.gif.2           100%[===================>]   1.61M  --.-KB/s    in 0.07s
#
# 2020-09-12 14:17:05 (22.2 MB/s) - ‘2bb.gif.2’ saved [1692256/1692256]

# %% [markdown]
# ### Variable

# %%
a="BigData "
b = 99.99
z=a+str(b)
print(z)
type(z)
# Out:
# BigData 99.99
# str

# %% [markdown]
# Numpy:
#
# A popular library for scientific computing in python.

# %%
import numpy as np

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# We import all the required Python libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np
# Custom table visualization 
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# %% [markdown]
# ### Misc:

# %%
# %pdb off
# Out:
# Automatic pdb calling has been turned OFF

# %%
import json
json.dumps([1, 'simple', 'list'])
f'Results of the'
# Out:
# 'Results of the'

# %% [markdown]
# ### Takeaways
# Press CTRL(command) + Space to get some help while typing

# %% [markdown]
# # References:

# %% [markdown]
# More information: https://en.wikipedia.org/wiki/Project_Jupyter
